# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns


data=pd.read_csv(r"C:\Users\Aksystems\Downloads\Iris.csv")
data.describe

X = data[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(6, 4))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.xticks(range(1, 11))
plt.grid(True)
plt.show()
optimal_clusters=3

kmeans = KMeans(n_clusters=optimal_clusters, init='k-means++', max_iter=300, n_init=10, random_state=42)
clusters = kmeans.fit_predict(X)

data['Cluster'] = clusters


plt.figure(figsize=(6,4))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Cluster', data=data, palette='viridis', s=100)
plt.title('KMeans Clustering of Iris Dataset')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Cluster')
plt.show()

plt.figure(figsize=(6,4))
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Cluster', data=data, palette='viridis', s=100)
plt.title('KMeans Clustering of Iris Dataset')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend(title='Cluster')
plt.show()

# %%
sklearn_inertia = []

for i in range(2, 8):
    model = KMeans(n_clusters=i)
    model.fit(X)
    plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=model.labels_)
    plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], s=500, marker='*', c='g')
    plt.title(f'KMeans with {i} Clusters')
    plt.xlabel('Sepal Length')
    plt.ylabel('Sepal Width')
    plt.show()
    sklearn_inertia.append((i, model.inertia_))

for k, inertia in sklearn_inertia:
    print(f'Number of Clusters: {k}, Inertia: {inertia}')

sklearn_inertia = []

for i in range(2, 8):
    model = KMeans(n_clusters=i)
    model.fit(X)
    plt.scatter(X.iloc[:, 2], X.iloc[:, 3], c=model.labels_)
    plt.scatter(model.cluster_centers_[:, 2], model.cluster_centers_[:, 3], s=500, marker='*', c='g')
    plt.title(f'KMeans with {i} Clusters')
    plt.xlabel('Petal Length')
    plt.ylabel('Petal Width')
    plt.show()
    sklearn_inertia.append((i, model.inertia_))

for k, inertia in sklearn_inertia:
    print(f'Number of Clusters: {k}, Inertia: {inertia}')
# Out:
# Number of Clusters: 2, Inertia: 152.36870647733906
# Number of Clusters: 3, Inertia: 78.940841426146
# Number of Clusters: 4, Inertia: 57.35501904761904
# Number of Clusters: 5, Inertia: 49.951650000000015
# Number of Clusters: 6, Inertia: 42.797023863636355
# Number of Clusters: 7, Inertia: 41.263562918788516
# Number of Clusters: 2, Inertia: 152.36870647733906
# Number of Clusters: 3, Inertia: 78.940841426146
# Number of Clusters: 4, Inertia: 57.317873214285704
# Number of Clusters: 5, Inertia: 46.56163015873016
# Number of Clusters: 6, Inertia: 44.72156212023271
# Number of Clusters: 7, Inertia: 35.189047863247865

# %%
model=KMeans(n_clusters=3)
model.fit(X)
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=model.labels_)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], s=500, marker='*', c='r')
plt.title('Kmeans with 3 clusters')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

model=KMeans(n_clusters=3)
model.fit(X)
plt.scatter(X.iloc[:,2], X.iloc[:,3], c=model.labels_)
plt.scatter(model.cluster_centers_[:,2], model.cluster_centers_[:,3], s=500, marker='*', c='r')
plt.title('Kmeans with 3 clusters')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()
